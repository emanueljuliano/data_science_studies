# %%
import pandas

# %%
pandas.__version__
# Out:
# '0.24.2'

# %%
import pandas as pd

# %%
pd.<TAB>
# Out:
#   File "<ipython-input-6-40b879790c84>", line 1
#     pd.<TAB>
#        ^
# SyntaxError: invalid syntax

# %%
pd?
